# %% [markdown]
# # Exploratory data analysis of accuracy
# Quick explorations for finding story -- eventually finding that events mentioning Trump are often less accurate than other political stories

# %% [markdown]
# ## Set up
# Set up some code to make R code work in notebook

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%R
#
# require(tidyverse)
# require(packcircles)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.5.1     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.4
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: tidyverse
# In addition: Warning messages:
# 1: package ‘ggplot2’ was built under R version 4.2.3
# 2: package ‘dplyr’ was built under R version 4.2.3

# %%
import pandas as pd

# %%
df = pd.read_csv("outcomes.csv")

# %%
df.head()
# Out:
#                                          conditionId  \
# 0  0x80e14125844dcb3dd3885290bc0a03626223a92b3a70...
# 1  0xd2c10628e74b85fae2c89b7a63642960d53bd7533652...
# 2  0xe91b26e02e0a35d164b243a1b1a70d5886441084e9da...
# 3  0x15a4bdba97f192528be64824720a0c7c70b5e6889e03...
# 4  0xa2279b962c1fa4616bf04f0d54a9a1f3b1697db528c4...
#
#                                             question               endDate  \
# 0  Mexican Presidential Election: Will Claudia Sh...  2024-05-30T00:00:00Z
# 1  Mexican Presidential Election: Will Xóchitl Gá...  2024-05-30T00:00:00Z
# 2  Finnish Presidential Election: Will Alexander ...  2024-01-25T00:00:00Z
# 3  Finnish Presidential Election: Will Pekka Haav...  2024-01-26T00:00:00Z
# 4  Finnish Presidential Election: Will Olli Rehn ...  2024-01-26T00:00:00Z
#
#                   createdAt              closedTime         volume  \
# 0  2024-01-08T17:51:23.211Z  2024-06-03 12:46:24+00  747925.287237
# 1  2024-01-08T17:51:23.253Z  2024-06-03 12:56:24+00  686502.795970
# 2  2024-01-12T21:22:28.466Z  2024-02-11 22:45:48+00  229590.359179
# 3    2024-01-12T21:22:28.5Z  2024-02-11 22:46:54+00  221233.399295
# 4   2024-01-12T21:24:28.98Z  2024-01-29 01:18:40+00   24894.852833
#
#         outcomes                                       clobTokenIds  \
# 0  ["Yes", "No"]  ['66121853294113159952019114952986597006629066...
# 1  ["Yes", "No"]  ['22630580583450969756139089277784718260497974...
# 2  ["Yes", "No"]  ['62471964247263026853388777058136273249949767...
# 3  ["Yes", "No"]  ['10192568547012047956206277235857302424258812...
# 4  ["Yes", "No"]  ['97949868482331892937872138123082774889228648...
#
#       prev_prices                                   winning_token_id  \
# 0  [0.945, 0.055]  6612185329411315995201911495298659700662906692...
# 1  [0.067, 0.933]  8302341301616374979366325632071186268124461735...
# 2  [0.925, 0.075]  6247196424726302685338877705813627324994976711...
# 3  [0.065, 0.935]  4011064234361833125898186449824752866740242277...
# 4  [0.007, 0.993]  7067612032162731035726594630728176773193840321...
#
#   winning_outcome correct_prediction  prediction_price
# 0             Yes               True             0.945
# 1              No               True             0.933
# 2             Yes               True             0.925
# 3              No               True             0.935
# 4              No               True             0.993

# %% [markdown]
# ## EDA

# %%
df["correct_prediction"].value_counts()
# Out:
# correct_prediction
# True     4058
# False     518
# Name: count, dtype: int64

# %%
df.to_clipboard()

# %%
df.groupby("correct_prediction")['volume'].mean().to_clipboard()

# %%
4058 / (4058 + 518)
# Out:
# 0.8868006993006993

# %%
# %%R -i df
#
# df %>%
#     ggplot(aes(x = prediction_price)) +
#     geom_histogram() +
#     theme_minimal()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 744 rows containing non-finite outside the scale range (`stat_bin()`).

# %%
# %%R -i df
#
# df %>%
#     filter(prediction_price < .95) %>%
#     ggplot(aes(x = prediction_price)) +
#     xlab("Correct Outcome End Price") +
#     geom_histogram() +
#     theme_minimal()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R -i df
#
# df %>%
#     ggplot(aes(x = volume)) +
#     geom_boxplot() +
#     theme_minimal()
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 32 rows containing non-finite outside the scale range
# (`stat_boxplot()`).

# %%
# %%R -i df
#
# df %>%
#     filter(prediction_price < .95) %>%
#     arrange(desc(volume)) %>%
#     head(10)
# Out:
#                                                             conditionId
# 431  0x9c66114d2dfe2139325cc7a408a5cd5d2e73b55d919e2141b3a0ed83fc15895d
# 835  0xc53c00d3ed7df96cb528e049ca2d8a6056b620a82bfffd3ad58d35c5f92c02d6
# 833  0x2010ff3939e8e664dd57369aa907bbaa6d03ae18be27fe3ab2f4cdcb95a8b2ab
# 831  0xafde9e890a2db339b6515cd75c2d09574dcaf731b483a1ef6ea0a3abc5ec8abd
# 2187 0xab66a7d5745fc4da8a30a67665ee1de894b740644e643a6c6ec39b17212e4df5
# 358  0x02bc0bbff054877a08cdc4f9ccf4e7606804bc05c27f5faccf26c6e1666a5558
# 1067 0x57f90c89879a5b5e69fad9c2a261fa6f44f3653001aa3a02446aed92aaff21bf
# 359  0xa923afcb8297e3ade170f2f8c088f3c277557fadef2c67054d72cc59f8504b2b
# 1066 0x1b60fead57018405d3555612030acdf7f46a35955bdc697445708be31188cd71
# 1274 0x6cc501fa617e3a46ececf6e3990fe1afeeaa6bc897d3c7049c005fd1bdc42c2f
#                                                                       question
# 431                                            Will Bitcoin hit $100k in 2024?
# 835  Will a Democrat win the popular vote and a Republican win the Presidency?
# 833                Will a Republican win the popular vote and the Presidency?
# 831                  Will a Democrat win the popular vote and the Presidency?
# 2187                                  Will Israel invade Lebanon in September?
# 358                    Will a Democrat win Pennsylvania Presidential Election?
# 1067                          Will Tim Walz be the 2024 Democratic VP nominee?
# 359                  Will a Republican win Pennsylvania Presidential Election?
# 1066                      Will Andy Beshear be the 2024 Democratic VP nominee?
# 1274     Fed decreases interest rates by 50+ bps after September 2024 meeting?
#                   endDate                   createdAt             closedTime
# 431  2024-12-30T12:00:00Z    2024-03-04T15:54:19.095Z 2024-12-05 04:46:26+00
# 835  2024-11-05T12:00:00Z 2024-05-14T16:10:31.756762Z 2024-11-07 00:39:51+00
# 833  2024-11-05T12:00:00Z 2024-05-14T16:02:14.999364Z 2024-11-07 00:49:10+00
# 831  2024-11-05T12:00:00Z 2024-05-14T15:49:07.689964Z 2024-11-07 01:23:52+00
# 2187 2024-09-30T12:00:00Z 2024-09-18T17:52:27.740401Z 2024-10-08 00:25:08+00
# 358  2024-11-05T12:00:00Z    2024-03-01T18:56:41.231Z 2024-11-07 12:53:28+00
# 1067 2024-08-22T12:00:00Z 2024-07-03T17:41:24.071756Z 2024-08-06 18:17:24+00
# 359  2024-11-05T12:00:00Z    2024-03-01T18:57:20.607Z 2024-11-06 20:29:57+00
# 1066 2024-08-22T12:00:00Z 2024-07-03T17:39:41.483147Z 2024-08-06 23:22:10+00
# 1274 2024-09-18T12:00:00Z 2024-07-25T14:47:42.952096Z 2024-09-18 21:09:08+00
#        volume      outcomes
# 431  22807236 ["Yes", "No"]
# 835  18758442 ["Yes", "No"]
# 833  15286458 ["Yes", "No"]
# 831  14756382 ["Yes", "No"]
# 2187 13817736 ["Yes", "No"]
# 358  12960333 ["Yes", "No"]
# 1067 12902914 ["Yes", "No"]
# 359  12519682 ["Yes", "No"]
# 1066 11499090 ["Yes", "No"]
# 1274 10906333 ["Yes", "No"]
#                                                                                                                                                             clobTokenIds
# 431   ['64903093311385616430821497488306433314807585397286521531639186532059591846310', '81337566243073271746608276915310766292424419662449021769243514448183489065187']
# 835   ['79290738821633012952251194646343347843753407986785745774809464443278141510795', '77538554173896015114453401012117630452637136665613691153928336127167320141811']
# 833   ['67648321332889562720702742465853245863647268672651902649177972067583993370930', '92848768921367210485187039202894189254214421377536495082521089096497548879926']
# 831    ['33573631646975967490303296373773410479817269960942179527425708594960263761938', '1245455071836736418858894114937610717733912531531312145552158827133486397267']
# 2187 ['82217519770356329016575074180915423709787654078325574175371380456084152665514', '103074846952659555203136280159144707438311771841831295577819182690870662076232']
# 358   ['96404870680531697292788145333705429762370661278621665925868256650124167091957', '67089287271692871221799799486468743524636060540186332703509386944410510992981']
# 1067  ['77290004420469807303121418983410594259783349435877463527461916026337527709766', '46151683995628303683848849165180379776066478517400313383689588032121505705166']
# 359   ['75951511934878014812323289513632732239356274541965522720897159608390126393735', '80692267952118231579739078214722079301718527753004959099480302005191158711065']
# 1066  ['80712420758383921582936584763126351359250932707204568764353087094189787249591', '69697709990438419490552378068319379723247957595044718630598282701780804270024']
# 1274  ['106191328358576540351439267765925450329859429577455659884974413809922495874408', '9214127416164770663428045171731158534317583924108886506080862617439489581164']
#           prev_prices
# 431  [0.6765, 0.3235]
# 835      [0.34, 0.66]
# 833      [0.24, 0.76]
# 831      [0.42, 0.58]
# 2187   [0.552, 0.448]
# 358    [0.465, 0.535]
# 1067 [0.2255, 0.7745]
# 359      [0.59, 0.41]
# 1066 [0.0515, 0.9485]
# 1274   [0.585, 0.415]
#                                                                    winning_token_id
# 431   64903093311385616430821497488306433314807585397286521531639186532059591846310
# 835   77538554173896015114453401012117630452637136665613691153928336127167320141811
# 833   67648321332889562720702742465853245863647268672651902649177972067583993370930
# 831    1245455071836736418858894114937610717733912531531312145552158827133486397267
# 2187 103074846952659555203136280159144707438311771841831295577819182690870662076232
# 358   67089287271692871221799799486468743524636060540186332703509386944410510992981
# 1067  77290004420469807303121418983410594259783349435877463527461916026337527709766
# 359   75951511934878014812323289513632732239356274541965522720897159608390126393735
# 1066  69697709990438419490552378068319379723247957595044718630598282701780804270024
# 1274 106191328358576540351439267765925450329859429577455659884974413809922495874408
#      winning_outcome correct_prediction prediction_price
# 431              Yes               TRUE           0.6765
# 835               No               TRUE           0.6600
# 833              Yes              FALSE           0.2400
# 831               No               TRUE           0.5800
# 2187              No              FALSE           0.4480
# 358               No               TRUE           0.5350
# 1067             Yes              FALSE           0.2255
# 359              Yes               TRUE           0.5900
# 1066              No               TRUE           0.9485
# 1274             Yes               TRUE           0.5850

# %%
# %%R -i df
#
# df %>%
#     filter(volume > 100000,
#           prediction_price < .95) %>%
#     ggplot(aes(x = prediction_price , y = (volume))) +
#     geom_point() +
#     theme_minimal()

# %%
# %%R -i df
# df <- df %>%
#     mutate(trump_flag = ifelse(grepl("trump",tolower(question)),"trump","no trump"))
#
# df %>%
#     filter(prediction_price < .95) %>%
#     ggplot(aes(x = prediction_price)) +
#     geom_histogram() +
#     facet_wrap(~trump_flag, scales = "free") +
#     theme_minimal()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R -i df
#
# df %>%
#     group_by(correct_prediction) %>%
#     tally() %>%
#     mutate(perc = n / sum(n))  %>%
#     ggplot(aes(x = 1, y = perc, fill = correct_prediction)) +
#     geom_bar(stat = "identity", position = "fill") +
#     ggtitle("predictions about trump are often less accurate\nthan other political events") +
#     theme_minimal()

# %%
# %%R -i df
#
# df %>%
#     filter(prediction_price < .95,
#            volume > 100000) %>%
#     group_by(correct_prediction) %>%
#     tally() %>%
#     mutate(perc = n / sum(n))  %>%
#     ggplot(aes(x = 1, y = perc, fill = correct_prediction)) +
#     geom_bar(stat = "identity", position = "fill") +
#     theme_minimal()

# %%
# %%R
#
# df <- df %>%
#     mutate(trump_flag = ifelse(grepl("trump",tolower(question)),"trump","no trump"))
#
# df %>%
#     filter(prediction_price < .95,
#            volume > 100000) %>%
#     group_by(trump_flag, correct_prediction) %>%
#     tally() %>%
#     group_by(trump_flag) %>%
#     mutate(perc = n / sum(n)) %>%
#     ggplot(aes(x = trump_flag, y = perc, fill = correct_prediction)) +
#     geom_bar(stat = "identity", position = "fill") +
#     geom_text(aes(label = perc))+
#     ggtitle("predictions about trump are often less accurate\nthan other political events") +
#     theme_minimal()

# %%
# %%R
#
# df <- df %>%
#     mutate(volume_flag = ifelse(volume > 500000,"high","low"))
#
# df %>%
#     filter(prediction_price < .95) %>%
#     group_by(volume_flag, correct_prediction) %>%
#     tally() %>%
#     group_by(volume_flag) %>%
#     mutate(perc = n / sum(n))  %>%
#     ggplot(aes(x = volume_flag, y = perc, fill = correct_prediction)) +
#     geom_bar(stat = "identity", position = "fill") +
#     ggtitle("Volume doesn't seem to affect accuracy") +
#     theme_minimal()

# %%
# %%R
# library(ggbeeswarm)
#
# df %>%
#     filter(prediction_price < .95,
#           volume > 100000) %>%
#     mutate(trump_flag = ifelse(grepl("trump",tolower(question)),"trump","no trump")) %>%
#     ggplot(aes(x = prediction_price, size = volume, fill = trump_flag)) +
#     geom_vline(xintercept =.5) +
#     geom_histogram() +
#     facet_wrap(~trump_flag, scales = "free") +
#     theme_minimal()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1: The following aesthetics were dropped during statistical transformation: size.
# ℹ This can happen when ggplot fails to infer the correct grouping structure in
#   the data.
# ℹ Did you forget to specify a `group` aesthetic or to convert a numerical
#   variable into a factor?
#
# R[write to console]: 2: The following aesthetics were dropped during statistical transformation: size.
# ℹ This can happen when ggplot fails to infer the correct grouping structure in
#   the data.
# ℹ Did you forget to specify a `group` aesthetic or to convert a numerical
#   variable into a factor?

# %%
# %%R -i df
#
# bubble <- df %>%
#     filter(prediction_price < .95,
#           volume > 100000) %>%
#     mutate(trump_flag = ifelse(grepl("trump",tolower(question)),"trump","no trump")) %>%
#     select(prediction_price, volume, trump_flag)
#
# head(bubble)
# Out:
#    prediction_price   volume trump_flag
# 0             0.945 747925.3   no trump
# 1             0.933 686502.8   no trump
# 2             0.925 229590.4   no trump
# 3             0.935 221233.4   no trump
# 9             0.295 997617.3      trump
# 34            0.805 642842.8   no trump

# %%
bubble = df[
    (df['prediction_price'] < 0.95) & 
    (df['volume'] > 100000)
].copy()  # Create a copy to avoid warnings

# Add trump_flag column
bubble['trump_flag'] = bubble['question'].str.lower().str.contains('trump').map({True: 'trump', False: 'no trump'})

# Select the required columns
bubble = bubble[['prediction_price', 'volume', 'trump_flag']]

bubble.to_clipboard(index=False)

# %%
# %%R
#
# df %>%
#     filter(prediction_price < .95) %>%
#     arrange(desc(volume)) %>%
#     head(5)
# Out:
#                                                             conditionId
# 431  0x9c66114d2dfe2139325cc7a408a5cd5d2e73b55d919e2141b3a0ed83fc15895d
# 835  0xc53c00d3ed7df96cb528e049ca2d8a6056b620a82bfffd3ad58d35c5f92c02d6
# 833  0x2010ff3939e8e664dd57369aa907bbaa6d03ae18be27fe3ab2f4cdcb95a8b2ab
# 831  0xafde9e890a2db339b6515cd75c2d09574dcaf731b483a1ef6ea0a3abc5ec8abd
# 2187 0xab66a7d5745fc4da8a30a67665ee1de894b740644e643a6c6ec39b17212e4df5
#                                                                       question
# 431                                            Will Bitcoin hit $100k in 2024?
# 835  Will a Democrat win the popular vote and a Republican win the Presidency?
# 833                Will a Republican win the popular vote and the Presidency?
# 831                  Will a Democrat win the popular vote and the Presidency?
# 2187                                  Will Israel invade Lebanon in September?
#                   endDate                   createdAt             closedTime
# 431  2024-12-30T12:00:00Z    2024-03-04T15:54:19.095Z 2024-12-05 04:46:26+00
# 835  2024-11-05T12:00:00Z 2024-05-14T16:10:31.756762Z 2024-11-07 00:39:51+00
# 833  2024-11-05T12:00:00Z 2024-05-14T16:02:14.999364Z 2024-11-07 00:49:10+00
# 831  2024-11-05T12:00:00Z 2024-05-14T15:49:07.689964Z 2024-11-07 01:23:52+00
# 2187 2024-09-30T12:00:00Z 2024-09-18T17:52:27.740401Z 2024-10-08 00:25:08+00
#        volume      outcomes
# 431  22807236 ["Yes", "No"]
# 835  18758442 ["Yes", "No"]
# 833  15286458 ["Yes", "No"]
# 831  14756382 ["Yes", "No"]
# 2187 13817736 ["Yes", "No"]
#                                                                                                                                                             clobTokenIds
# 431   ['64903093311385616430821497488306433314807585397286521531639186532059591846310', '81337566243073271746608276915310766292424419662449021769243514448183489065187']
# 835   ['79290738821633012952251194646343347843753407986785745774809464443278141510795', '77538554173896015114453401012117630452637136665613691153928336127167320141811']
# 833   ['67648321332889562720702742465853245863647268672651902649177972067583993370930', '92848768921367210485187039202894189254214421377536495082521089096497548879926']
# 831    ['33573631646975967490303296373773410479817269960942179527425708594960263761938', '1245455071836736418858894114937610717733912531531312145552158827133486397267']
# 2187 ['82217519770356329016575074180915423709787654078325574175371380456084152665514', '103074846952659555203136280159144707438311771841831295577819182690870662076232']
#           prev_prices
# 431  [0.6765, 0.3235]
# 835      [0.34, 0.66]
# 833      [0.24, 0.76]
# 831      [0.42, 0.58]
# 2187   [0.552, 0.448]
#                                                                    winning_token_id
# 431   64903093311385616430821497488306433314807585397286521531639186532059591846310
# 835   77538554173896015114453401012117630452637136665613691153928336127167320141811
# 833   67648321332889562720702742465853245863647268672651902649177972067583993370930
# 831    1245455071836736418858894114937610717733912531531312145552158827133486397267
# 2187 103074846952659555203136280159144707438311771841831295577819182690870662076232
#      winning_outcome correct_prediction prediction_price trump_flag volume_flag
# 431              Yes               TRUE           0.6765   no trump        high
# 835               No               TRUE           0.6600   no trump        high
# 833              Yes              FALSE           0.2400   no trump        high
# 831               No               TRUE           0.5800   no trump        high
# 2187              No              FALSE           0.4480   no trump        high
